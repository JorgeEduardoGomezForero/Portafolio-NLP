# %% [markdown]
# # Nube de Palabras
#
# ## Taller 9: Nube de Palabras: Información del día de los muertos

# %% [markdown]
# ### 1. Se importan las librerias de trabajo

# %%
import numpy as np
import pandas as pd

#para instalar en anaconda -->> conda install -c conda-forge wordcloud
from wordcloud import WordCloud
from wordcloud import ImageColorGenerator

from nltk.corpus import stopwords
stopwords = stopwords.words('spanish')

import matplotlib.pyplot as plt
import PIL.Image
from IPython.display import display

# %% [markdown]
# ### 2. Se realiza el cargue de la infomación, para este ejercicio es un archivo csv.

# %%
ruta = "C:/03_Jorge/01_Especialización_Analitica/02_Semestre/04 Electiva Fundamentos NLP/20201031/"
data = pd.read_csv(ruta + 'Día_todos_los_muertos.csv')
data.head()
# Out:
#                                                texto
# 0  1 y 2 de noviembre son los días que en México ...
# 1  El origen del día de muertos sucedió en la cul...
# 2  En el Día de Muertos, según la tradición, los ...
# 3  Ofrendar, en el Día de Muertos, es compartir c...
# 4  El Día de Muertos es una tradición mexicana qu...

# %% [markdown]
# ### 3. Visualización nube de palabras

# %%
palabras = data.texto.str.cat(sep=' ')

wordcloud = WordCloud(width=800, height=400,
                     max_font_size=150, max_words=250,
                     background_color='white', colormap='gist_heat',
                     stopwords=stopwords).generate(palabras) # https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html

plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ### 4. Cargue de imagen para imprimir nube de palabras

# %%
calabaza = PIL.Image.open(ruta + "calabaza2.png")
display(calabaza)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1574x1420 at 0x20D3B2C8508>

# %%
mask = np.array(calabaza)
mask
# Out:
# array([[[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
# ...

# %% [markdown]
# ### 5. Nube de palabras impresa en la imagen

# %%
palabras = data.texto.str.cat(sep=' ')
wordcloud = WordCloud(width=800, height=400,
                     max_font_size=150, max_words=250,
                     background_color='white', colormap='copper_r',
                     stopwords=stopwords,
                     mask=mask, contour_width=0.5, contour_color='black').generate(palabras) # https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html

wordcloud.to_file("calabaza.png")

plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
